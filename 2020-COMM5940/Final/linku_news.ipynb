# %%
from flask import Flask, render_template, jsonify
# import pymysql.cursors #initialise PyMysql module
import MySQLdb

app = Flask(__name__)
# CORS(app)

# connection = pymysql.connect(host="localhost", 
connection = MySQLdb.connect(host="localhost",
                     user="root",   
                     passwd="root", 
                     db="linku",   
                     charset='utf8mb4')      
                     # cursorclass=pymysql.cursors.DictCursor)

@app.route("/")
def home():
    with connection.cursor() as cursor:
        sql = "SELECT * FROM newsall"
        cursor.execute(sql)
        result = cursor.fetchall()
    connection.close()
    final_result = [list(i) for i in result]
    dataset=[]
    dict={}
    for i in final_result:
        dict['title'] = i[0]
        dict['cover'] = i[1]
        dict['brief'] = i[2]
        dict['url'] = i[3]
        dataset.append(dict.copy()) #markers.append(fld.copy())
    
    return render_template('news_all.html', dataset=dataset)

if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9029, app)
# Out:
#  * Running on http://localhost:9029/ (Press CTRL+C to quit)
# [2020-04-01 12:48:45,125] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-eb54c6cd3530>", line 33, in home
#     return render_template('news_all.html', dataset=dataset)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\templating.py", line 140, in render_template
#     ctx.app,
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\flask\templating.py", line 120, in _render
#     rv = template.render(context)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\asyncsupport.py", line 76, in render
#     return original_render(self, *args, **kwargs)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 1008, in render
#     return self.environment.handle_exception(exc_info, True)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 780, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\_compat.py", line 37, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Koe.Shu\Python Workshop\templates\news_base.html", line 7, in template
#     {% extends "footer.html"}
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 1005, in render
#     return concat(self.root_render_func(self.new_context(vars)))
#   File "C:\Users\Koe.Shu\Python Workshop\templates\news_all.html", line 11, in root
#     <div class="d-flex justify-content-between align-items-center">
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     code = environment.compile(source, name, filename)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 591, in compile
#     self.handle_exception(exc_info, source_hint=source_hint)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 780, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\_compat.py", line 37, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Koe.Shu\Python Workshop\templates\news_base.html", line 7, in template
#     {% extends "footer.html"}
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\environment.py", line 497, in _parse
#     return Parser(self, source, name, encode_filename(filename)).parse()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 901, in parse
#     result = nodes.Template(self.subparse(), lineno=1)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 883, in subparse
#     rv = self.parse_statement()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 130, in parse_statement
#     return getattr(self, 'parse_' + self.stream.current.value)()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 274, in parse_extends
#     node.template = self.parse_expression()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 432, in parse_expression
#     return self.parse_condexpr()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 437, in parse_condexpr
#     expr1 = self.parse_or()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 450, in parse_or
#     left = self.parse_and()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 459, in parse_and
#     left = self.parse_not()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 470, in parse_not
#     return self.parse_compare()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 474, in parse_compare
#     expr = self.parse_math1()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 496, in parse_math1
#     left = self.parse_concat()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 507, in parse_concat
#     args = [self.parse_math2()]
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 517, in parse_math2
#     left = self.parse_pow()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 528, in parse_pow
#     left = self.parse_unary()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 546, in parse_unary
#     node = self.parse_primary()
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\parser.py", line 564, in parse_primary
#     next(self.stream)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\lexer.py", line 359, in __next__
#     self.current = next(self._iter)
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\lexer.py", line 562, in wrap
#     for lineno, token, value in stream:
#   File "C:\Users\Koe.Shu\Anaconda3\lib\site-packages\jinja2\lexer.py", line 683, in tokeniter
#     filename)
# jinja2.exceptions.TemplateSyntaxError: unexpected '}'
# 127.0.0.1 - - [01/Apr/2020 12:48:45] "GET / HTTP/1.1" 500 -
